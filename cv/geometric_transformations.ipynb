# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
# !ls
# Out:
# Untitled.png                    image_conversion.py
# geometric_transformations.ipynb img
# grayscale.ipynb

# %%
gr = 'img/albert-einstein_gray.jpeg'
cl = 'img/tulips.jpeg'

I_gray = cv2.imread(gr, cv2.IMREAD_GRAYSCALE)
I_BGR = cv2.imread(cl)

# %%
plt.imshow(I_gray)

# %%
plt.imshow(I_gray, cmap='gray');

# %%
plt.imshow(I_BGR);

# %%
plt.imshow(I_BGR[::-1]); # ooooops

# %%
plt.imshow(I_BGR[:,:,::-1]);
